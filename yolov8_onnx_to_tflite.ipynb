# %%
# %pip uninstall -y onnx onnx-tf tensorflow tensorflow-addons keras
# %pip install onnx==1.14.0 onnx-tf==1.10.0 tensorflow==2.15.0 keras==2.15.0 tensorflow-addons==0.22.0
# Out:
# WARNING: Skipping onnx as it is not installed.
# WARNING: Skipping onnx-tf as it is not installed.
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0
# WARNING: Skipping tensorflow-addons as it is not installed.
# Found existing installation: keras 3.8.0
# Uninstalling keras-3.8.0:
#   Successfully uninstalled keras-3.8.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 95.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.1/226.1 kB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.3/475.3 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.3/612.3 kB 47.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 71.5 MB/s eta 0:00:00
# ...

# %%
import sys
sys.setrecursionlimit(10000)  # Increase recursion limit

# %%
# %pip install onnx2tf
# %pip install onnx-graphsurgeon
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 3.1 MB/s eta 0:00:00
# ...

# %%
# %pip install -U ai_edge_litert
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 112.6 MB/s eta 0:00:00
# ...

# %%
# %pip install --upgrade onnx==1.16.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 91.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.14.0
#     Uninstalling onnx-1.14.0:
#       Successfully uninstalled onnx-1.14.0
# ...

# %%
# %pip install sng4onnx

# %%
# !onnx2tf -i /content/best.onnx -o output_model_general -otfv1pb -odrqt
# Out:
# Model optimizing started ============================================================
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/onnx2tf/onnx2tf.py", line 668, in convert
#     result = subprocess.check_output(
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/subprocess.py", line 466, in check_output
#     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/usr/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# ...

# %%
# !onnx2tf -i /content/best.onnx -o output_model -otfv1pb -oiqt -iqd float32 -oqd int8
# Out:
# Model optimizing started ============================================================
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/onnx2tf/onnx2tf.py", line 668, in convert
#     result = subprocess.check_output(
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/subprocess.py", line 466, in check_output
#     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/usr/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# ...

# %%
# prompt: download outputfolder

from google.colab import files
# !zip -r /content/output_model.zip /content/output_model
files.download('/content/output_model_general.zip')
# Out:
# updating: content/output_model/ (stored 0%)
# updating: content/output_model/best_float16.tflite (deflated 15%)
# updating: content/output_model/best_full_integer_quant_with_int16_act.tflite (deflated 32%)
# updating: content/output_model/variables/ (stored 0%)
# updating: content/output_model/variables/variables.index (deflated 33%)
# updating: content/output_model/variables/variables.data-00000-of-00001 (deflated 85%)
# updating: content/output_model/best_float32.tflite (deflated 18%)
# updating: content/output_model/saved_model.pb (deflated 13%)
# updating: content/output_model/best_integer_quant_with_int16_act.tflite (deflated 32%)
# updating: content/output_model/best_dynamic_range_quant.tflite (deflated 36%)
# updating: content/output_model/best_float32.pb (deflated 12%)
# updating: content/output_model/assets/ (stored 0%)
# updating: content/output_model/fingerprint.pb (stored 0%)
# updating: content/output_model/best_integer_quant.tflite (deflated 29%)
# ...

# %%
# prompt: download output_model_generalfolder

# !zip -r /content/output_model_general.zip /content/output_model_general
files.download('/content/output_model_general.zip')
# Out:
#   adding: content/output_model_general/ (stored 0%)
#   adding: content/output_model_general/best_float16.tflite (deflated 15%)
#   adding: content/output_model_general/variables/ (stored 0%)
#   adding: content/output_model_general/variables/variables.index (deflated 33%)
#   adding: content/output_model_general/variables/variables.data-00000-of-00001 (deflated 85%)
#   adding: content/output_model_general/best_float32.tflite (deflated 18%)
#   adding: content/output_model_general/saved_model.pb (deflated 13%)
#   adding: content/output_model_general/best_dynamic_range_quant.tflite (deflated 36%)
#   adding: content/output_model_general/best_float32.pb (deflated 12%)
#   adding: content/output_model_general/assets/ (stored 0%)
#   adding: content/output_model_general/fingerprint.pb (stored 0%)
